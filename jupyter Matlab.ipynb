% %% [markdown]
% # Introduction

% %% [markdown]
% Hello, this is an ipython notebook with matlab kernel test

% %%
addpath('/Users/aidasaglinskas/Google Drive/Aidas/Categories_Experiment/Scripts/');

% %%
mat = rand(10);

figure;bar(rand(1,10))
    xticklabels(repmat({'bar'},1,10))
    
figure;add_numbers_to_mat(mat)
xticklabels(repmat({'x'},1,10))
yticklabels(repmat({'y'},1,10))

% %%
n = 10;
v1 = randn(n,1);
v2 = randn(n,1);
[H,P,CI,STATS] = ttest2(v1,v2);
t_statement(STATS,P);
% Out:
% t(18) = -0.75,p = 0.4613

% %%
mat = rand(20,10);
cmat = corr(mat);

Y = pdist(cmat,'correlation');
Z = linkage(Y,'ward');
[Z_atlas distmat] = get_Z_atlas(Z);
figure(1)
[h x perm] = dendrogram(Z);
drawnow
[h(1:end).LineWidth] = deal(2);
    title('Random Dendrogram')
    
figure(2)
add_numbers_to_mat(distmat);title('Ward distance random data')
drawnow
% Out:
% ...
% > In linkage (line 171)
