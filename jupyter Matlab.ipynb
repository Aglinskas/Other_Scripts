% %%
a = 4
% Out:
% a =
%
%      4

% %%
mat = rand(10);

% %%
imagesc(mat)

% %%
add_numbers_to_mat(mat)

% %%
beta_fn = '/Users/aidasaglinskas/Google Drive/Aidas/Categories_Experiment/Group_analysis3_18subs/spmF_0004.nii';
surf_fn = '/Users/aidasaglinskas/Documents/MATLAB/spm12/canonical/cortex_5124.surf.gii';
